# %%
#@title #Inference
model_path = 'D:/experiments/base' # '.'
min_len = 0 #@param {type:"number", min:5, max:1024, step:1}
sample_num = 1 #@param {type:"number", min:1, max:50, step:1}
top_p = 0.7 #@param {type:"number", min:0, max:1}
model_size = 'large' #@param {type:"string"}
model_type = 'PT' #@param {type:"string"} # GPT2/PT
extraName = '' #'-finetune'
config_fn = 'configs/{}.json'.format(model_size) #'lm/configs/{}.json'.format(model_type) #@param {type:"string"}
#ckpt_fn = '{}/experimentsSymbolic_{}{}_model.ckpt-188000'.format(model_path, model_size, extraName) #@param {type:"string"}
ckpt_fn = '{}/model.ckpt-0'.format(model_path)
filters = '' #@param {type:"string"} # text;
saveFlag = False #@param {type:"boolean"}from scripts import demodemo.wraper(top_p, config_fn, ckpt_fn, min_len, sample_num, saveFlag, filters)

# %%
#from scripts import demo
import demo
demo.wraper(top_p, config_fn, ckpt_fn, min_len, sample_num, saveFlag, filters, 
            context='user', modelType=model_type, max_num_points=30, max_num_vars=5)

# Some cool Example As Input:

# <SOS_X>[[0.1], [0.2], [0.31], [0.41], [0.51], [0.62], [0.72], [0.82], [0.93], [1.03], [1.13], [1.24], [1.34], [1.44], [1.55], [1.65], [1.76], [1.86], [1.96], [2.07], [2.17], [2.27], [2.38], [2.48], [2.58], [2.69], [2.79], [2.89], [3.0], [3.1]]<EOS_X><SOS_Y>[-2.54, -1.97, -1.6, -1.34, -1.12, -0.89, -0.67, -0.45, -0.18, 0.08, 0.38, 0.74, 1.12, 1.54, 2.06, 2.61, 3.29, 3.99, 4.78, 5.77, 6.79, 7.93, 9.37, 10.85, 12.51, 14.58, 16.71, 19.1, 22.07, 25.11]<EOS_Y><SOS_EQ>exp(x1)*log(x1)<EOS_EQ>
# Out:
# WARNING:tensorflow:From C:\Users\vpcom\OneDrive - University of Waterloo\Projects\symbolicgpt2\modeling.py:143: dense (from tensorflow.python.keras.legacy_tf_layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From C:\Users\vpcom\Anaconda3\lib\site-packages\tensorflow\python\keras\legacy_tf_layers\core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer_v1) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From C:\Users\vpcom\Anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py:201: batch_gather (from tensorflow.python.ops.array_ops) is deprecated and will be removed after 2017-10-25.
# Instructions for updating:
# `tf.batch_gather` is deprecated, please use `tf.gather` with `batch_dims=-1` instead.
# INFO:tensorflow:Restoring parameters from D:/experiments/base/model.ckpt-0
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#
# NotFoundError: 2 root error(s) found.
#   (0) Not found: Key newslm/layer12/LayerNorm_mlp_ln0/beta not found in checkpoint
# 	 [[{{node save/RestoreV2}}]]
#   (1) Not found: Key newslm/layer12/LayerNorm_mlp_ln0/beta not found in checkpoint
# 	 [[{{node save/RestoreV2}}]]
# 	 [[save/RestoreV2/_103]]
# 0 successful operations.
# 0 derived errors ignored.
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py in restore(self, sess, save_path)
#    1298         sess.run(self.saver_def.restore_op_name,
# -> 1299                  {self.saver_def.filename_tensor_name: save_path})
#    1300     except errors.NotFoundError as err:
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     957       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 958                          run_metadata_ptr)
#     959       if run_metadata:
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1180       results = self._do_run(handle, final_targets, final_fetches,
# -> 1181                              feed_dict_tensor, options, run_metadata)
#    1182     else:
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1383                     'disable_meta_optimizer = True')
# -> 1384       raise type(e)(node_def, op, message)
#    1385
#
# NotFoundError: 2 root error(s) found.
#   (0) Not found: Key newslm/layer12/LayerNorm_mlp_ln0/beta not found in checkpoint
# 	 [[node save/RestoreV2 (defined at C:\Users\vpcom\OneDrive - University of Waterloo\Projects\symbolicgpt2\demo.py:275) ]]
#   (1) Not found: Key newslm/layer12/LayerNorm_mlp_ln0/beta not found in checkpoint
# 	 [[node save/RestoreV2 (defined at C:\Users\vpcom\OneDrive - University of Waterloo\Projects\symbolicgpt2\demo.py:275) ]]
# 	 [[save/RestoreV2/_103]]
# 0 successful operations.
# 0 derived errors ignored.
#
# Original stack trace for 'save/RestoreV2':
#   File "C:\Users\vpcom\Anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\vpcom\Anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\traitlets\config\application.py", line 664, in launch_instance
#     app.start()
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 153, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\vpcom\Anaconda3\lib\asyncio\base_events.py", line 538, in run_forever
#     self._run_once()
#   File "C:\Users\vpcom\Anaconda3\lib\asyncio\base_events.py", line 1782, in _run_once
#     handle._run()
#   File "C:\Users\vpcom\Anaconda3\lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tornado\ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tornado\ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tornado\gen.py", line 787, in inner
#     self.run()
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tornado\gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 361, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 541, in execute_request
#     user_expressions, allow_stdin,
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-00084163f33c>", line 4, in <module>
#     context='user', modelType=model_type, max_num_points=30, max_num_vars=5)
#   File "C:\Users\vpcom\OneDrive - University of Waterloo\Projects\symbolicgpt2\demo.py", line 423, in wraper
#     return main()
#   File "C:\Users\vpcom\OneDrive - University of Waterloo\Projects\symbolicgpt2\demo.py", line 275, in main
#     saver = tf.train.Saver()
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 836, in __init__
#     self.build()
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 848, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 886, in _build
#     build_restore=build_restore)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 516, in _build_internal
#     restore_sequentially, reshape)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 336, in _AddRestoreOps
#     restore_sequentially)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 583, in bulk_restore
#     return io_ops.restore_v2(filename_tensor, names, slices, dtypes)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tensorflow\python\ops\gen_io_ops.py", line 1524, in restore_v2
#     name=name)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 744, in _apply_op_helper
#     attrs=attr_protos, op_def=op_def)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 3485, in _create_op_internal
#     op_def=op_def)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 1949, in __init__
#     self._traceback = tf_stack.extract_stack()
#
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\tensorflow\python\training\py_checkpoint_reader.py in get_tensor(self, tensor_str)
#      69     return CheckpointReader.CheckpointReader_GetTensor(
# ---> 70         self, compat.as_bytes(tensor_str))
#      71   # TODO(b/143319754): Remove the RuntimeError casting logic once we resolve the
#
# RuntimeError: Key _CHECKPOINTABLE_OBJECT_GRAPH not found in checkpoint
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py in restore(self, sess, save_path)
#    1308       try:
# -> 1309         names_to_keys = object_graph_key_mapping(save_path)
#    1310       except errors.NotFoundError:
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py in object_graph_key_mapping(checkpoint_path)
#    1626   reader = py_checkpoint_reader.NewCheckpointReader(checkpoint_path)
# -> 1627   object_graph_string = reader.get_tensor(trackable.OBJECT_GRAPH_PROTO_KEY)
#    1628   object_graph_proto = (trackable_object_graph_pb2.TrackableObjectGraph())
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\training\py_checkpoint_reader.py in get_tensor(self, tensor_str)
#      73   except RuntimeError as e:
# ---> 74     error_translator(e)
#      75
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\training\py_checkpoint_reader.py in error_translator(e)
#      34       'matching files for') in error_message:
# ---> 35     raise errors_impl.NotFoundError(None, None, error_message)
#      36   elif 'Sliced checkpoints are not supported' in error_message or (
#
# NotFoundError: Key _CHECKPOINTABLE_OBJECT_GRAPH not found in checkpoint
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-2-00084163f33c> in <module>
#       2 import demo
#       3 demo.wraper(top_p, config_fn, ckpt_fn, min_len, sample_num, saveFlag, filters,
# ----> 4             context='user', modelType=model_type, max_num_points=30, max_num_vars=5)
#       5
#       6 # Some cool Example As Input:
#
# ~\OneDrive - University of Waterloo\Projects\symbolicgpt2\demo.py in wraper(top_p, config_fn, ckpt_fn, min_len, sample_num, saveFlag, filters, context, modelType, max_num_points, max_num_vars)
#     421     if filters != '':
#     422         sys.argv += ['-filters', '{}'.format(filters)]
# --> 423     return main()
#     424
#     425 if __name__ == "__main__":
#
# ~\OneDrive - University of Waterloo\Projects\symbolicgpt2\demo.py in main()
#     274
#     275             saver = tf.train.Saver()
# --> 276             saver.restore(sess, args.ckpt_fn)
#     277             print('🍺Model loaded. \n')
#     278             #text =  sys.stdin.readlines() #input()
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py in restore(self, sess, save_path)
#    1313         # a helpful message (b/110263146)
#    1314         raise _wrap_restore_error_with_msg(
# -> 1315             err, "a Variable name or other graph key that is missing")
#    1316
#    1317       # This is an object-based checkpoint. We'll print a warning and then do
#
# NotFoundError: Restoring from checkpoint failed. This is most likely due to a Variable name or other graph key that is missing from the checkpoint. Please ensure that you have not altered the graph expected based on the checkpoint. Original error:
#
# 2 root error(s) found.
#   (0) Not found: Key newslm/layer12/LayerNorm_mlp_ln0/beta not found in checkpoint
# 	 [[node save/RestoreV2 (defined at C:\Users\vpcom\OneDrive - University of Waterloo\Projects\symbolicgpt2\demo.py:275) ]]
#   (1) Not found: Key newslm/layer12/LayerNorm_mlp_ln0/beta not found in checkpoint
# 	 [[node save/RestoreV2 (defined at C:\Users\vpcom\OneDrive - University of Waterloo\Projects\symbolicgpt2\demo.py:275) ]]
# 	 [[save/RestoreV2/_103]]
# 0 successful operations.
# 0 derived errors ignored.
#
# Original stack trace for 'save/RestoreV2':
#   File "C:\Users\vpcom\Anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\vpcom\Anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\traitlets\config\application.py", line 664, in launch_instance
#     app.start()
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 153, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\vpcom\Anaconda3\lib\asyncio\base_events.py", line 538, in run_forever
#     self._run_once()
#   File "C:\Users\vpcom\Anaconda3\lib\asyncio\base_events.py", line 1782, in _run_once
#     handle._run()
#   File "C:\Users\vpcom\Anaconda3\lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tornado\ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tornado\ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tornado\gen.py", line 787, in inner
#     self.run()
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tornado\gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 361, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 541, in execute_request
#     user_expressions, allow_stdin,
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-00084163f33c>", line 4, in <module>
#     context='user', modelType=model_type, max_num_points=30, max_num_vars=5)
#   File "C:\Users\vpcom\OneDrive - University of Waterloo\Projects\symbolicgpt2\demo.py", line 423, in wraper
#     return main()
#   File "C:\Users\vpcom\OneDrive - University of Waterloo\Projects\symbolicgpt2\demo.py", line 275, in main
#     saver = tf.train.Saver()
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 836, in __init__
#     self.build()
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 848, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 886, in _build
#     build_restore=build_restore)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 516, in _build_internal
#     restore_sequentially, reshape)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 336, in _AddRestoreOps
#     restore_sequentially)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 583, in bulk_restore
#     return io_ops.restore_v2(filename_tensor, names, slices, dtypes)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tensorflow\python\ops\gen_io_ops.py", line 1524, in restore_v2
#     name=name)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 744, in _apply_op_helper
#     attrs=attr_protos, op_def=op_def)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 3485, in _create_op_internal
#     op_def=op_def)
#   File "C:\Users\vpcom\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 1949, in __init__
#     self._traceback = tf_stack.extract_stack()
